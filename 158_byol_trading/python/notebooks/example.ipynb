# %% [markdown]
# # BYOL Trading: Bootstrap Your Own Latent
# Learning robust stock features using Master-Apprentice asymmetrical networks without explicit negative comparisons.

# %%
from model import CNN1DEncoder, BYOL
print('BYOL Components Ready.')
