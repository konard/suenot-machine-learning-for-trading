# %% [markdown]
# # SwAV Trading: Swapping Assignments between Views
# Learning robust stock features and distinct market regime classifications simultaneously through Online Clustering (Prototypes) and the Sinkhorn-Knopp algorithm.

# %%
from model import CNN1DEncoder, SwAV
print('SwAV Components Ready.')
